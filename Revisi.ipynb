# %% [markdown]
# <h2 style='text-align:center; color:lightcoral'><b> [Airbnb Listings Bangkok]</b></h1>
# <h5 style='text-align: center;color:pink'> [Chandra Driastama]</h2>

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:lightcoral'>Section 1 |</span><span style='color:pink'> Introduction</span></b>
#
# ____
#
# <a id="basic"></a>
# ### <b><span style='color:red'> About the Company</span></b>
#
# <div class="alert alert-block alert-success">
# <b><span style='color:darkgreen'>
#
# Airbnb memiliki sejarah panjang dalam inovasi dan pengembangan yang berpusat pada pelanggan. Didirikan pada tahun 2008 oleh visioner teknologi Brian Chesky, Joe Gebbia, dan Nathan Blecharczyk, perusahaan ini awalnya berfokus pada penyediaan penginapan jangka pendek dengan memanfaatkan ruang yang tidak terpakai di rumah-rumah orang. Selama bertahun-tahun, Airbnb memperluas penawarannya untuk mencakup pengalaman unik, persewaan jangka panjang, dan layanan perjalanan lainnya.
# Misi kami adalah memberdayakan wisatawan melalui akses ke akomodasi unik di seluruh dunia, yang memungkinkan mereka untuk merasakan destinasi dengan cara yang lebih autentik dan personal. Kami didorong oleh nilai-nilai inti kami yaitu integritas, inovasi, dan kepuasan pelanggan. Visi kami adalah menjadi penyedia layanan perjalanan dan akomodasi terkemuka di dunia, yang diakui atas komitmen kami terhadap keunggulan dan kemampuan kami untuk memberikan pengalaman yang tak terlupakan bagi pengguna kami.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:red'> Business Context</span></b>
#
# <div class="alert alert-block alert-success">
# <b><span style='color:darkgreen'>
#
# Airbnb Bangkok telah mengalami pertumbuhan yang signifikan selama beberapa tahun terakhir, menjadi salah satu pilihan utama bagi wisatawan yang mencari akomodasi di ibu kota Thailand. Meskipun demikian, terdapat beberapa tipe kamar yang terus mengalami tingkat okupansi yang rendah dan kontribusi pendapatan yang tidak optimal. Masalah ini menjadi perhatian khusus karena dapat mempengaruhi profitabilitas keseluruhan dan daya saing Airbnb di pasar yang semakin kompetitif.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:red'> Business Task</span></b>
#
#
#
# <div class="alert alert-block alert-success">
# <b><span style='color:darkgreen'> Probem statement:</span></b><br>
#
#
# Meskipun Airbnb di Bangkok telah mengalami pertumbuhan signifikan, terdapat beberapa tipe ruangan yang mengalami tingkat okupansi rendah dan kontribusi pendapatan yang tidak optimal. Data menunjukkan bahwa tipe ruangan tertentu memiliki tingkat pemesanan yang jauh lebih rendah dibandingkan dengan tipe kamar lainnya, yang berdampak negatif pada total pendapatan dan utilisasi properti. Dalam industri yang sangat kompetitif ini, penting bagi Airbnb untuk memahami dan mengatasi masalah ini agar dapat meningkatkan pendapatan dan pengalaman pelanggan secara keseluruhan. Oleh karena itu, tim eCommerce berupaya mendiagnosis penyebab rendahnya penjualan pada tipe ruangan tertentu dan mengembangkan strategi yang dapat ditindaklanjuti untuk meningkatkan performa penjualan tipe kamar tersebut ke depannya.
#
# **Pertanyaan yang ingin dijawab adalah :**
#
# -Apa alasan utama rendahnya tingkat okupansi untuk tipe ruangan di daerah tertentu di Airbnb Bangkok?
#
# -Apakah wilayah mempengaruhi harga sewa tipe ruangan di air bnb?
#
# Analisis ini akan mencakup data pelanggan dari Januari 2021 hingga Desember 2023, dengan fokus pada perilaku pemesanan, metrik keterlibatan, harga, fitur kamar, dan interaksi dukungan pelanggan. Tipe kamar yang telah memiliki tingkat pemesanan tinggi akan dikecualikan untuk memastikan data mencerminkan pola interaksi yang relevan dan bermakna. Keberhasilan analisis akan diukur dari wawasan yang dapat ditindaklanjuti yang dihasilkan dan dampaknya terhadap tingkat okupansi dan pendapatan tipe kamar yang kurang laku. Secara khusus, kami bermaksud meraih peningkatan okupansi sebesar 10% untuk tipe kamar yang kurang laku pada tahun fiskal berikutnya.
#
# Dengan mengatasi masalah ini, kami berharap dapat mengoptimalkan strategi penjualan, meningkatkan tingkat okupansi, dan pada akhirnya meningkatkan pendapatan keseluruhan dari semua tipe kamar di Airbnb Bangkok.

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:red'> Scenario</span></b>
#
# <div class="alert alert-block alert-success">
# <b>Implementasi Sistem Rekomendasi Harga Dinamis untuk Tamu Airbnb:</b><br>
#
# **Stakeholders Utama :**
#
# **Director of Sales :**  Bertanggung jawab atas strategi peningkatan pelanggan secara keseluruhan.
#
# **Marketing Team & E-commerce specialist:** Menggunakan wawasan untuk menginformasikan pengembangan,saran,dan penetapan harga tipe ruangan.
#
# **Sales executive :**  Temuan ini akan mempengaruhi upaya penjangkauan dan penjualan kepada pelanggan.
#
# **Asumsi :**
# Kami mengasumsikan bahwa data yang tersedia akurat dan komprehensif, mencakup semua interaksi pelanggan yang relevan. Selain itu, kami mengasumsikan bahwa faktor eksternal yang mempengaruhi tingkat okupansi, seperti kondisi ekonomi, tetap relatif stabil selama periode analisis.
#
# **Tujuan Analisis :**
# Keberhasilan analisis akan diukur dari wawasan yang dapat ditindaklanjuti yang dihasilkan dan dampaknya terhadap tingkat okupansi dan pendapatan tipe kamar yang kurang laku. Secara khusus, kami bermaksud meraih peningkatan okupansi sebesar 10% untuk tipe kamar yang kurang laku pada tahun fiskal berikutnya.
#
# Dengan mengatasi masalah ini, kami berharap dapat mengoptimalkan strategi penjualan, meningkatkan tingkat okupansi, dan pada akhirnya meningkatkan pendapatan keseluruhan dari semua tipe kamar di Airbnb Bangkok.

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:lightcoral'>Section 2 |</span><span style='color:pink'> Data Examination</span></b>
#
# ____
#
# <a id="basic"></a>
# ### <b><span style='color:red'> </span></b>

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:red'> Data Size: amount and range </span></b>

# %% [markdown]
# **Airbnb Listings Bangkok Data Dictionary**
#
# | Feature                        | Description                                                                              |
# |--------------------------------|------------------------------------------------------------------------------------------|
# | `id`                           | Airbnb's unique identifier for the listing                                               |
# | `name`                         | Name of the listing                                                                      |
# | `host_id`                      | Airbnb's unique identifier for the host/user                                             |
# | `host_name`                    | Name of the host. Usually, just the first name(s)                                         |
# | `neighbourhood`                | The neighbourhood is geocoded using the latitude and longitude against defined boundaries |
# | `latitude`                     | Uses the World Geodetic System (WGS84) projection for latitude                           |
# | `longitude`                    | Uses the World Geodetic System (WGS84) projection for longitude                          |
# | `room_type`                    | Type of room being offered (Entire home/apt, Private room, Shared room, Hotel)           |
# | `price`                        | Daily price in local currency                                                            |
# | `minimum_nights`               | The minimum number of night stays for the listing                                        |
# | `number_of_reviews`            | The number of reviews the listing has received                                           |
# | `last_review`                  | The date of the last/newest review                                                       |
# | `calculated_host_listings_count`| The number of listings the host has in the current scrape in the city/region geography   |
# | `availability_365`             | The availability of the listing for 365 days in the future                               |
# | `number_of_reviews_ltm`        | The number of reviews the listing has received in the last 12 months                     |

# %% [markdown]
# **Import Library**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
from folium.plugins import MarkerCluster
from scipy.stats import normaltest, chi2_contingency, mannwhitneyu, ttest_ind
from tabulate import tabulate


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Load dataset**

# %%
df = pd.read_csv("Airbnb Listings Bangkok.csv")
df.head()
# Out:
#                                           Unnamed: 0      id  \
# 0                                                  0   27934
# 1  1,27979,"Easy going landlord,easy place",12054...     NaN
# 2                                                  2   28745
# 3                                                  3   35780
# 4                                                  4  941865
#
#                                              name host_id   host_name  \
# 0                 Nice room with superb city view  120437      Nuttee
# 1                                             NaN     NaN         NaN
# 2               modern-style apartment in Bangkok  123784  Familyroom
# 3  Spacious one bedroom at The Kris Condo Bldg. 3  153730     Sirilak
# 4                      Suite Room 3 at MetroPoint  610315       Kasem
#
#   neighbourhood  latitude  longitude        room_type   price minimum_nights  \
# 0   Ratchathewi  13.75983  100.54134  Entire home/apt  1905.0              3
# ...

# %% [markdown]
# **Cek informasi dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15958 entries, 0 to 15957
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      15958 non-null  object
#  1   id                              13360 non-null  object
#  2   name                            13350 non-null  object
#  3   host_id                         13358 non-null  object
#  4   host_name                       13358 non-null  object
#  5   neighbourhood                   13358 non-null  object
#  6   latitude                        13358 non-null  object
#  7   longitude                       13358 non-null  object
#  8   room_type                       13358 non-null  object
#  9   price                           13358 non-null  float64
#  10  minimum_nights                  13358 non-null  object
#  11  number_of_reviews               13358 non-null  object
# ...

# %% [markdown]
# - **Beberapa kolom memiliki nilai yang hilang, terutama pada kolom last_review dan reviews_per_month.**
# - **Sebagian besar kolom bertipe object, yang mungkin perlu dikonversi ke tipe numerik atau tanggal untuk analisis lebih lanjut.**
# - **Kolom number_of_reviews_ltm; kemungkinan memiliki kesalahan ketik yang perlu diperbaiki.**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                2598
# name                              2608
# host_id                           2600
# host_name                         2600
# neighbourhood                     2600
# latitude                          2600
# longitude                         2600
# room_type                         2600
# price                             2600
# minimum_nights                    2600
# number_of_reviews                 2600
# last_review                       7691
# reviews_per_month                 7691
# calculated_host_listings_count    2600
# availability_365                  2601
# number_of_reviews_ltm;            2603
# dtype: int64

# %% [markdown]
# **Dari dataset di atas terdapat banyak missing value di semua kolom**

# %%
# Plot distribusi fitur 'price'
plt.figure(figsize=(7, 7))
sns.distplot(df['price'])
plt.title('Price Distribution Plot', size=15, weight='bold');

# %% [markdown]
# Plot di atas menunjukkan distribusi harga dari listing Airbnb. Distribusi sangat miring ke kanan, dengan mayoritas harga berkumpul di dekat nilai rendah, dan sedikit data yang memiliki harga sangat tinggi. Ini menunjukkan adanya beberapa nilai outlier yang jauh lebih besar dari kebanyakan data lainnya, sehingga menghasilkan distribusi yang tidak seimbang. Hal ini umum terjadi pada data harga, di mana ada beberapa listing dengan harga jauh lebih tinggi daripada rata-rata.
#
# Distribusi seperti ini sering kali memerlukan transformasi (misalnya logaritmik) atau penghapusan outlier agar analisis lebih representatif dan tidak didominasi oleh beberapa harga ekstrem.

# %% [markdown]
# **Cek jumlah properti AirBnb di Thailand**

# %%
# Cek jumlah properti berdasarkan neighbourhood group dan tipenya
print(f"Jumlah properti di tiap neighbourhood group:\n{df['neighbourhood'].value_counts()}")
print(f"\nJumlah tiap tipe properti:\n{df['room_type'].value_counts()}")
# Out:
# Jumlah properti di tiap neighbourhood group:
# Vadhana                 1826
# Khlong Toei             1748
# Huai Khwang              989
# Ratchathewi              891
# Bang Rak                 707
# Sathon                   664
# Phra Nakhon              557
# Phra Khanong             461
# Chatu Chak               441
# Parthum Wan              385
# Din Daeng                362
# Phaya Thai               351
# Bang Na                  341
# Suanluang                320
# Khlong San               304
# Bang Kapi                218
# Bang Phlat               195
# Bang Sue                 191
# Yan na wa                164
# Don Mueang               152
# Thon buri                148
# Pra Wet                  131
# Bangkok Noi              131
# Lat Krabang              130
# Phasi Charoen            129
# Bang Kho laen            117
# Bang Khen                110
# Lak Si                   106
# Pom Prap Sattru Phai     105
# Samphanthawong            97
# ...

# %%
# Grouping tipe properti berdasarkan neighbourhood group
df.groupby(['neighbourhood', 'room_type'])['room_type'].count()
# Out:
# neighbourhood    room_type
# 100.5486         1                   1
# 13.7085          1500                1
# 13.7505          1339                1
# Bang Bon         Entire home/apt     2
#                  Private room        3
#                                     ..
# Wang Thong Lang  Shared room         3
# Yan na wa        Entire home/apt    99
#                  Hotel room          3
#                  Private room       59
#                  Shared room         3
# Name: room_type, Length: 169, dtype: int64

# %% [markdown]
# **Cek harga menggunakan median pada AirBnb**

# %%
# Cek median price untuk tiap neighbourhood group
df_median_price = df.groupby(by=['neighbourhood']).agg({'price':'median'}).reset_index()
df_median_price = df_median_price.set_index('neighbourhood')
df_median_price = df_median_price.sort_values('price', ascending =False)
df_median_price.head()
# Out:
#                  price
# neighbourhood
# Nong Chok       2539.0
# Parthum Wan     2486.0
# Samphanthawong  2000.0
# Vadhana         2000.0
# Bang Rak        1874.0

# %%
# Plot harga median untuk tiap tipe properti di setiap neighbourhood group
from IPython.display import display

neighbour_pivot = df.pivot_table(index='neighbourhood', columns='room_type', values='price', aggfunc='median')
display(neighbour_pivot)

pivot_plot = neighbour_pivot.plot.bar(stacked=True, figsize=(12, 7))
pivot_plot.set_xlabel('Neighbourhood Groups')
pivot_plot.set_ylabel('Median Price')
pivot_plot.set_title('Median Price of Room Types');
# Out:
# room_type                1  1339  1500  Entire home/apt  Hotel room  \
# neighbourhood
# 100.5486              44.0   NaN   NaN              NaN         NaN
# 13.7085                NaN   NaN   3.0              NaN         NaN
# 13.7505                NaN   1.0   NaN              NaN         NaN
# Bang Bon               NaN   NaN   NaN           1600.0         NaN
# Bang Kapi              NaN   NaN   NaN            950.0       600.0
# Bang Khae              NaN   NaN   NaN            900.0       750.0
# Bang Khen              NaN   NaN   NaN            900.0      1286.0
# Bang Kho laen          NaN   NaN   NaN           1194.5       900.0
# Bang Khun thain        NaN   NaN   NaN           4478.5         NaN
# Bang Na                NaN   NaN   NaN           1000.0      2200.0
# Bang Phlat             NaN   NaN   NaN            900.0      2100.0
# Bang Rak               NaN   NaN   NaN           2264.0      1563.0
# Bang Sue               NaN   NaN   NaN            924.0         NaN
# ...

# %% [markdown]
# Grafik di atas menunjukkan harga median untuk berbagai jenis kamar di tiap kelompok lingkungan (neighbourhood groups). Setiap warna mewakili tipe kamar yang berbeda, termasuk *Entire home/apt*, *Hotel room*, *Private room*, dan *Shared room*.
#
# Beberapa kelompok lingkungan memiliki harga median yang lebih tinggi, terutama untuk tipe *Shared room* yang terlihat memiliki harga yang lebih tinggi di beberapa area. Variasi harga antar tipe kamar dan antar lingkungan menunjukkan perbedaan signifikan dalam penawaran harga yang mungkin terkait dengan lokasi, fasilitas, atau popularitas area tertentu.
#
# Grafik ini membantu memahami kecenderungan harga berdasarkan tipe kamar di berbagai lingkungan, yang berguna untuk analisis pasar dan strategi penetapan harga.

# %% [markdown]
# **Cek ulang dataset agar data sesuai dan tidak ada perubahan sebelum di proses**

# %%
#Mengecek kembali mengenai missing value dan tipe data
#Menampilkan jumlah baris dan kolom dari dataset
print(f'Jumlah baris dan kolom: {df.shape}')

#Memberikan penilaian awal terhadap dataset
pd.DataFrame({
    'Type': df.dtypes,
    'N/A (%)': df.isna().mean() * 100,
    'Unique': df.nunique(),
    'Sample': [df[col].unique() for col in df.columns]
})
# Out:
# Jumlah baris dan kolom: (15958, 17)
#                                    Type    N/A (%)  Unique  \
# Unnamed: 0                       object   0.000000   15956
# id                               object  16.280236   13360
# name                             object  16.342900   12380
# host_id                          object  16.292769    5807
# host_name                        object  16.292769    4731
# neighbourhood                    object  16.292769      53
# latitude                         object  16.292769    8610
# longitude                        object  16.292769    9168
# room_type                        object  16.292769       7
# price                           float64  16.292769    2780
# minimum_nights                   object  16.292769      80
# number_of_reviews                object  16.292769     277
# last_review                      object  48.195263    1557
# reviews_per_month               float64  48.195263     491
# ...

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:lightcoral'>Section 3 |</span><span style='color:pink'> Data Transformation</span></b>

# %% [markdown]
# <a id="basic"></a>
# ### <b><span style='color:red'> Data Cleaning</span></b>

# %% [markdown]
# **Data Preprocessing**

# %%
#membuat data baru
dfClean = df.dropna(subset='name')

# %%
#menghapus kolom yang tidak di gunakan
dfClean.drop(columns=['number_of_reviews_ltm;','Unnamed: 0','id','last_review','reviews_per_month','host_id'],axis=1,inplace=True)

# %%
dfClean.isnull().sum()
# Out:
# name                              0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  1
# dtype: int64

# %% [markdown]
# - **Cek data yang terduplikat**

# %%
dfClean.duplicated().sum()
# Out:
# 9

# %% [markdown]
# - **Hapus data terduplikat**

# %%
#Terdapat data duplikat, hapus data duplikat
dfClean.drop_duplicates(keep='first', inplace=True)

# %%
dfClean.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - **Mengganti nilai unik dengan dictionary**

# %%
# Mengganti nilai '1500', '1', '1339' di kolom room_type
replace_dict = {
    '1500': 'Entire home/apt',
    '1': 'Private room',
    '1339': 'Shared room'
}

dfClean['room_type'] = dfClean['room_type'].replace(replace_dict)

# %%
#Mengganti nilai tersebut di kolom minimum nights
dfClean['minimum_nights'] = dfClean['minimum_nights'].replace([3.000e+00, 6.000e+01, 7.000e+00, 1.000e+00, 2.500e+02, 2.000e+00, 1.500e+01], [3, 61, 7, 1, 250, 2, 15])

# %%
# Mengganti nilai '100.5486', '13.7085', '13.7505' di kolom neighbourhood
replace_dict_neighbourhood = {
    '100.5486': 'Phra Pradaeng',
    '13.7085': 'Samut Sakhon',
    '13.7505': 'Nonthaburi'
}

dfClean['neighbourhood'] = dfClean['neighbourhood'].replace(replace_dict_neighbourhood)

# %% [markdown]
# **Tujuan mengganti nilai unik adalah memudahkan untuk proses analisis data dan membuat dataset semakin valid dengan mengubah nilai unik di semua kolom**

# %% [markdown]
# - **Cek ulang dataset setelah dilakukan preprocessing**

# %%
dfClean.head(10)
# Out:
#                                               name   host_name  neighbourhood  \
# 0                  Nice room with superb city view      Nuttee    Ratchathewi
# 2                modern-style apartment in Bangkok  Familyroom      Bang Kapi
# 3   Spacious one bedroom at The Kris Condo Bldg. 3     Sirilak      Din Daeng
# 4                       Suite Room 3 at MetroPoint       Kasem      Bang Kapi
# 5                   NEw Pro!!  Bungalow Bkk Centre    Wimonpak  Bang Kho laen
# 6                  Condo with Chaopraya River View    Athitaya     Rat Burana
# 7                  1 chic bedroom apartment in BKK    Jiraporn     Chatu Chak
# 9                    Standard Room Decor do Hostel      Somsak     Khlong San
# 10                   Sathorn Terrace Apartment(61)         Tor       Bang Rak
# 11                  2BR apt in a cozy neighborhood        Jing     Phaya Thai
#
#     latitude  longitude        room_type   price minimum_nights  \
# ...

# %% [markdown]
# - **Mengubah harga 0 bath menjadi minimun 1 bath**

# %%
# Cek harga sewa yang bernilai 0
dfClean[dfClean['price'] == 0]['price'].count()
# Out:
# 1

# %% [markdown]
# - **Convert kolom bersifat object menjadi numeric**

# %%
# Convert 'minimum_nights' to numeric, coercing errors to NaN
dfClean['minimum_nights'] = pd.to_numeric(dfClean['minimum_nights'], errors='coerce')
dfClean['latitude'] = pd.to_numeric(dfClean['latitude'], errors='coerce')
dfClean['longitude'] = pd.to_numeric(dfClean['longitude'], errors='coerce')
dfClean['number_of_reviews'] = pd.to_numeric(dfClean['number_of_reviews'], errors='coerce')
dfClean['calculated_host_listings_count'] = pd.to_numeric(dfClean['calculated_host_listings_count'], errors='coerce')
dfClean['availability_365'] = pd.to_numeric(dfClean['availability_365'], errors='coerce')

# %% [markdown]
# - **Cek listing yang memiliki review kurang dari 2**

# %%
# Cek listing yang memiliki review kurang dari 2
dfClean[dfClean['number_of_reviews'] < 2]['number_of_reviews'].count()
# Out:
# 6552

# %% [markdown]
# - **Cek correlation matrix**

# %%
# Correlation matrix
plt.figure(figsize=(15, 12))
palette=sns.diverging_palette(20, 220, n=256)
corr = dfClean.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt='.2f', cmap=palette, square=True, linewidths=.5)
plt.title('Correlation Matrix', size=15, weight='bold');

# %% [markdown]
# ### Penjelasan Correlation Matrix
#
# - **Tujuan**: Matriks korelasi digunakan untuk mengidentifikasi hubungan linier antara variabel-variabel dalam dataset.
# - **Interpretasi**:
#   - Nilai korelasi berkisar dari **-1** hingga **1**:
#     - **1**: Korelasi positif sempurna (ketika satu variabel naik, variabel lain juga naik).
#     - **-1**: Korelasi negatif sempurna (ketika satu variabel naik, variabel lain turun).
#     - **0**: Tidak ada hubungan linier antara variabel.
#   - Skala warna menunjukkan kekuatan dan arah hubungan (merah untuk negatif, biru untuk positif).
#
# - **Hasil Penting**:
#   - **`price`**: Memiliki korelasi yang sangat lemah dengan semua variabel lain (dekat dengan 0), menunjukkan bahwa faktor lain mungkin lebih memengaruhi harga.
#   - Variabel geografis seperti **`latitude`** dan **`longitude`** memiliki hubungan lemah terhadap variabel lainnya.
#   - **`availability_365`** dan **`minimum_nights`** juga memiliki korelasi yang lemah dengan variabel lainnya.
#
# - **Kesimpulan**:
#   Korelasi yang lemah di seluruh variabel menunjukkan tidak ada hubungan linier yang signifikan, sehingga pendekatan lain mungkin diperlukan untuk analisis yang lebih mendalam (misalnya analisis multivariat atau clustering).

# %% [markdown]
# - **Cek Outliers Airbnb**

# %%
# Plot boxplot untuk mengecek outliers
dfClean.boxplot(rot=90);

# %% [markdown]
# ### Penjelasan Boxplot
#
# - **Tujuan**: Boxplot digunakan untuk menganalisis distribusi data dan mendeteksi outlier pada setiap variabel.
#
# - **Interpretasi**:
#   - **Sumbu horizontal**: Variabel dalam dataset (`latitude`, `longitude`, `price`, dll.).
#   - **Sumbu vertikal**: Rentang nilai setiap variabel.
#   - **Outlier**: Ditampilkan sebagai titik-titik di luar whisker (garis vertikal yang mencakup sebagian besar data).
#   - **Median**: Garis horizontal dalam kotak (menunjukkan nilai tengah).
#
# - **Hasil Penting**:
#   - **`price`**: Terlihat memiliki banyak outlier dengan nilai ekstrem yang jauh lebih tinggi dari data lainnya. Hal ini menunjukkan beberapa entri harga yang mungkin tidak realistis.
#   - Variabel lain seperti **`latitude`**, **`longitude`**, dan **`availability_365`** memiliki rentang nilai yang lebih konsisten tanpa banyak outlier signifikan.
#
# - **Kesimpulan**:
#   - Data **`price`** memerlukan perhatian khusus, seperti transformasi logaritmik atau pembuangan outlier untuk meningkatkan analisis.
#   - Variabel lain tampaknya lebih stabil, namun penting untuk mempertimbangkan konteksnya sebelum melanjutkan ke analisis lebih lanjut.

# %% [markdown]
# - **Membuat fungsi untuk mengolah outliers**

# %%
# Membuat fungsi untuk mengecek outliers
def find_anomalies(data):
    q1 = data.quantile(0.25)
    q3 = data.quantile(0.75)
    iqr = q3 - q1
    limit = iqr*1.5
    print(f'IQR: {iqr}')

    limit_bawah = q1 - limit
    limit_atas = q3 + limit
    print(f'limit_bawah: {limit_bawah}')
    print(f'limit_atas: {limit_atas}')

# %%
# Outliers pada fitur price
find_anomalies(dfClean['price'])
# Out:
# IQR: 1529.0
# limit_bawah: -1393.5
# limit_atas: 4722.5

# %%
# Cek deskriptif statistik kolom price
dfClean['price'].describe()
# Out:
# count    1.334100e+04
# mean     2.993174e+03
# std      2.167322e+04
# min      0.000000e+00
# 25%      9.000000e+02
# 50%      1.449000e+03
# 75%      2.429000e+03
# max      1.100000e+06
# Name: price, dtype: float64

# %%
# Cek price > $4722.5
dfClean[dfClean['price'] > 4722.5].count()['price']
# Out:
# 1130

# %%
# Melakukan filtering pada data
dfClean = dfClean[(dfClean['price'] <= 4722.5)]

# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.distplot(df['price'], ax=axes[0])
sns.distplot(dfClean['price'], ax=axes[1])
axes[0].set_xlabel('Price')
axes[1].set_xlabel('Range Selected Price');

# %% [markdown]
# Grafik kiri: Distribusi harga secara keseluruhan dengan rentang nilai yang sangat lebar. Terlihat bahwa sebagian besar data harga terkonsentrasi di dekat nilai yang rendah, sementara sisa distribusi memanjang jauh ke kanan, menunjukkan adanya harga-harga yang sangat tinggi tetapi jarang (skewed right).
#
# Grafik kanan: Distribusi harga yang dipilih pada rentang yang lebih sempit, memungkinkan untuk melihat detail data di sekitar harga-harga yang lebih umum. Distribusi ini menunjukkan puncak di sekitar harga 1000 dan menurun secara bertahap hingga mendekati 5000, memperlihatkan rentang harga yang lebih sering muncul di dataset.
#
# Analisis ini menunjukkan bahwa sebagian besar listing memiliki harga rendah hingga sedang, dengan beberapa listing harga sangat tinggi yang menjadi outliers.

# %%
# Menegcek OUtlier minimum_nights
dfClean.minimum_nights.plot(kind='box', vert=False, figsize=(15,3)) 
plt.title("Grafik Boxplot untuk Variabel 'minimum_nights'", size = "15")
# Out:
# Text(0.5, 1.0, "Grafik Boxplot untuk Variabel 'minimum_nights'")

# %%
# Outliers pada fitur price
find_anomalies(dfClean['minimum_nights'])
# Out:
# IQR: 6.0
# limit_bawah: -8.0
# limit_atas: 16.0

# %%
# Melakukan filtering pada data
dfClean = dfClean[(dfClean['minimum_nights'] <= 16)]

# Plot distribusi data sebelum dan sesudah filtering
fig, axes = plt.subplots(1,2, figsize=(21, 6))
sns.distplot(dfClean['minimum_nights'], ax=axes[1])
axes[0].set_xlabel('minimum_nights')
axes[1].set_xlabel('Range Selected minimum_nights');

# %%
dfClean.head(10)
# Out:
#                                               name host_name neighbourhood  \
# 0                  Nice room with superb city view    Nuttee   Ratchathewi
# 3   Spacious one bedroom at The Kris Condo Bldg. 3   Sirilak     Din Daeng
# 4                       Suite Room 3 at MetroPoint     Kasem     Bang Kapi
# 6                  Condo with Chaopraya River View  Athitaya    Rat Burana
# 7                  1 chic bedroom apartment in BKK  Jiraporn    Chatu Chak
# 9                    Standard Room Decor do Hostel    Somsak    Khlong San
# 10                   Sathorn Terrace Apartment(61)       Tor      Bang Rak
# 11                  2BR apt in a cozy neighborhood      Jing    Phaya Thai
# 12    Comfy bedroom near River pier & BTS  Taksin.       Tor        Sathon
# 13                budget hotel bangkok near subway      Mimi     Din Daeng
#
#     latitude  longitude        room_type   price  minimum_nights  \
# 0   13.75983  100.54134  Entire home/apt  1905.0             3.0
# ...

# %%
# Correlation matrix
plt.figure(figsize=(15, 12))
palette=sns.diverging_palette(20, 220, n=256)
corr = dfClean.corr(method='pearson')
sns.heatmap(corr, annot=True, fmt='.2f', cmap=palette, square=True, linewidths=.5)
plt.title('Correlation Matrix', size=15, weight='bold');

# %% [markdown]
# ### Penjelasan Correlation Matrix
#
# - **Tujuan**: Menampilkan korelasi antara variabel dalam dataset, termasuk variabel baru `min_income`.
#
# - **Hasil Utama**:
#   - **`min_income`** memiliki korelasi positif kuat dengan **`minimum_nights`** (0.81), menunjukkan hubungan linier yang signifikan.
#   - **`price`** menunjukkan korelasi moderat dengan **`min_income`** (0.35), mengindikasikan bahwa peningkatan pendapatan minimum mungkin berhubungan dengan harga yang lebih tinggi.
#   - Sebagian besar variabel lain menunjukkan korelasi lemah atau mendekati nol, yang berarti tidak ada hubungan linier yang signifikan.
#
# - **Kesimpulan**:
#   - Hubungan antara **`min_income`** dan variabel lain seperti **`price`** serta **`minimum_nights`** patut diteliti lebih lanjut untuk memahami pengaruhnya terhadap data.
#   - Korelasi lemah pada sebagian besar variabel lain menunjukkan pentingnya mengeksplorasi faktor tambahan untuk menjelaskan hubungan dalam dataset ini.

# %% [markdown]
# <a id="numerical"></a>
# # <b><span style='color:lightcoral'>Section 4 |</span><span style='color:pink'> Data Analysis</span></b>

# %%
# Mengelompokkan data berdasarkan 'room_type' dan menghitung jumlah entri dalam setiap kategori
room_type_counts = dfClean['room_type'].value_counts()

# Membuat pie chart
plt.pie(room_type_counts, labels=room_type_counts.index, autopct='%1.1f%%')

# Menambahkan judul
plt.title('Distribution Room_type')

# Menampilkan pie chart
plt.show()

# %% [markdown]
# Diagram lingkaran ini menunjukkan distribusi berbagai jenis kamar atau ruang hunian dalam kumpulan data. Kategorinya adalah:
#
# - Seluruh rumah/apartemen: 49,1% dari distribusi
# - Kamar pribadi: 42,0% dari distribusi
# - Kamar hotel: 4,5% dari distribusi
# - Kamar bersama: 4,4% dari distribusi
#
# Diagram ini memberikan representasi visual dari proporsi relatif setiap jenis ruang hunian dalam keseluruhan kumpulan data.

# %%
# Mengelompokkan data berdasarkan 'host_name' dan menghitung jumlah penginapan per tuan rumah
listing_count = dfClean['host_name'].value_counts()

# Mengambil 10 tuan rumah dengan jumlah penginapan terbanyak
top_10_hosts = listing_count.head(10)

# Membuat grafik batang
plt.bar(top_10_hosts.index, top_10_hosts.values)

# Mengatur label sumbu x dan y serta judul
plt.xlabel('Host Name')
plt.ylabel('Jumlah Penginapan')
plt.title('Jumlah Daftar Penginapan berdasarkan pemilik')

# Memutar teks pada label sumbu x agar lebih mudah dibaca
plt.xticks(rotation=90)

# Menampilkan grafik batang
plt.show()

# %% [markdown]
# Berdasarkan grafik diatas pemilik penginapan terbanyak dimiliki oleh curry diseluruh Thailand

# %%
# Jumlah property berbasarkan neighbourhood
plt.figure(figsize = (24,8))
ax = sns.countplot(x='neighbourhood', data=dfClean, order=dfClean['neighbourhood'].value_counts().index)
abs_values = dfClean['neighbourhood'].value_counts(ascending=False).values
ax.bar_label(container=ax.containers[0], labels=abs_values)

ax.set_title('Jumlah property berbasarkan neighbourhood')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Mencari Persebaran Room Type**

# %%
# Persebaran room type
sns.scatterplot(data = dfClean, x = 'longitude', y = 'latitude', hue = 'room_type')
plt.title ("Persebaran Property berdasarkan 'room_type'")
plt.xlabel("longitude")
plt.ylabel("latitude")
# Out:
# Text(0, 0.5, 'latitude')

# %%
# Menghitung Minimum income dengan mengkalikan minimum night dan price
dfClean['min_income'] = dfClean.minimum_nights * dfClean.price
dfClean.head()
# Out:
#                                              name host_name neighbourhood  \
# 0                 Nice room with superb city view    Nuttee   Ratchathewi
# 3  Spacious one bedroom at The Kris Condo Bldg. 3   Sirilak     Din Daeng
# 4                      Suite Room 3 at MetroPoint     Kasem     Bang Kapi
# 6                 Condo with Chaopraya River View  Athitaya    Rat Burana
# 7                 1 chic bedroom apartment in BKK  Jiraporn    Chatu Chak
#
#    latitude  longitude        room_type   price  minimum_nights  \
# 0  13.75983  100.54134  Entire home/apt  1905.0             3.0
# 3  13.78823  100.57256     Private room  1286.0             7.0
# 4  13.76872  100.63338     Private room  1905.0             1.0
# 6  13.68556  100.49535     Private room  1558.0             3.0
# 7  13.82925  100.56737  Entire home/apt  1461.0             1.0
#
#    number_of_reviews  calculated_host_listings_count  availability_365  \
# ...

# %%
dfClean['room_type'].value_counts()
# Out:
# Entire home/apt    4769
# Private room       4079
# Shared room         441
# Hotel room          431
# Name: room_type, dtype: int64

# %% [markdown]
# **Membagi cluster area di Thailand menjadi 4 wilayah**

# %%
area_mapping = {
    'Bang Sue': 'North Bangkok',
    'Lak Si': 'North Bangkok',
    'Sai Mai': 'North Bangkok',
    'Chatu Chak' : 'North Bangkok',
    'Don Mueang': 'North Bangkok',
    'Bang Khen': 'North Bangkok',
    'Chatuchak': 'North Bangkok',
    'Bang Kapi': 'East Bangkok',
    'Lat Krabang': 'East Bangkok',
    'Wang Thong Lang': 'East Bangkok',
    'Nong Chok': 'East Bangkok',
    'Bueng Kum': 'East Bangkok',
    'Min Buri': 'East Bangkok',
    'Saphan Sung' :'East Bangkok',
    'Khlong Sam Wa': 'East Bangkok',
    'Lat Phrao' : 'East Bangkok',
    'Khan Na Yao': 'East Bangkok',
    'Bangkok Yai': 'West Bangkok',
    'Khlong San' : 'West Bangkok',
    'Thon buri' : 'West Bangkok',
    'Thon Buri': 'West Bangkok',
    'Thung khru': 'West Bangkok',
    'Bang Phlat': 'West Bangkok',
    'Taling Chan': 'West Bangkok',
    'Phasi Charoen': 'West Bangkok',
    'Bang Khae': 'West Bangkok',
    'Bangkok Noi': 'West Bangkok',
    'Sathon': 'South Bangkok',
    'Phra Khanong' : 'South Bangkok',
    'Yan Nawa': 'South Bangkok',
    'Suanluang': 'South Bangkok',
    'Bang Na' : 'South Bangkok',
    'Bang Kho laen' : 'South Bangkok',
    'Bang Kho Laem': 'South Bangkok',
    'Rat Burana': 'South Bangkok',
    'Yan na wa': 'South Bangkok',
    'Ratchathewi': 'Central Bangkok',
    'Pra Wet' : 'Central Bangkok',
    'Parthum Wan': 'Central Bangkok',
    'Din Daeng': 'Central Bangkok',
    'Khlong Toei': 'Central Bangkok',
    'Phaya Thai': 'Central Bangkok',
    'Vadhana': 'Central Bangkok',
    'Huai Khwang': 'Central Bangkok',
    'Bang Rak': 'Central Bangkok',
    'Pathum Wan': 'Central Bangkok',
    'Phra Nakhon': 'Central Bangkok',
    'Dusit': 'Central Bangkok',
    'Pom Prap Sattru Phai': 'Central Bangkok',
    'Samphanthawong': 'Central Bangkok',
    'Bang Bon': 'Outer Western Bangkok',
    'Chom Thong': 'Outer Western Bangkok',
    'Thawi Watthana': 'Outer Western Bangkok',
    'Bang Khun thain': 'Outer Western Bangkok',
    'Nong Khaem': 'Outer Western Bangkok'
}

dfClean['area'] = dfClean['neighbourhood'].map(area_mapping)
dfClean.head(5)
# Out:
#                                              name host_name neighbourhood  \
# 0                 Nice room with superb city view    Nuttee   Ratchathewi
# 3  Spacious one bedroom at The Kris Condo Bldg. 3   Sirilak     Din Daeng
# 4                      Suite Room 3 at MetroPoint     Kasem     Bang Kapi
# 6                 Condo with Chaopraya River View  Athitaya    Rat Burana
# 7                 1 chic bedroom apartment in BKK  Jiraporn    Chatu Chak
#
#    latitude  longitude        room_type   price  minimum_nights  \
# 0  13.75983  100.54134  Entire home/apt  1905.0             3.0
# 3  13.78823  100.57256     Private room  1286.0             7.0
# 4  13.76872  100.63338     Private room  1905.0             1.0
# 6  13.68556  100.49535     Private room  1558.0             3.0
# 7  13.82925  100.56737  Entire home/apt  1461.0             1.0
#
#    number_of_reviews  calculated_host_listings_count  availability_365  \
# ...

# %% [markdown]
# **Data Analysis**

# %%
price_mean = round(dfClean['price'], 2).mean()
price_mean
# Out:
# 1624.410390946502

# %%
# Groupby berdasarkan 'area' dan menghitung rata-rata harga
area_price = dfClean.groupby('area')['price'].mean().reset_index()

# Plot bar
plt.figure(figsize=(10, 6))
sns.barplot(data=area_price.sort_values(by='price'), x='price', y='area', palette='viridis')
plt.xlabel('Rata-rata Harga (Baht)', fontsize=14)
plt.ylabel('Area', fontsize=14)
plt.title('Rata-rata Harga Tempat Penginapan Berdasarkan Area', fontsize=16)
plt.grid(True)
plt.show()

# %%
# Groupby berdasarkan 'area' dan menghitung standar deviasi harga
std_dev_price = dfClean.groupby('area')['price'].std().reset_index()

# Membulatkan standar deviasi ke dua desimal
std_dev_price['price'] = std_dev_price['price'].round(2)

# Menampilkan hasil standar deviasi
print(std_dev_price)
# Out:
#                     area    price
# 0        Central Bangkok  1003.33
# 1           East Bangkok   899.32
# 2          North Bangkok   796.61
# 3  Outer Western Bangkok   836.64
# 4          South Bangkok   846.08
# 5           West Bangkok   951.45

# %%
sns.histplot(data=dfClean,x='availability_365')
# Out:
# <Axes: xlabel='availability_365', ylabel='Count'>

# %%
# Groupby berdasarkan 'room_type' dan menghitung rata-rata harga
roomtype_price = dfClean.groupby('area')['availability_365'].mean().reset_index()

# Plot bar
plt.figure(figsize=(10, 6))
sns.barplot(data=roomtype_price.sort_values(by='availability_365'), x='availability_365', y='area', palette='viridis')
plt.xlabel('Rata-rata Availability', fontsize=14)
plt.ylabel('Area', fontsize=14)
plt.title('Rata-rata Availability Penginapan Berdasarkan Area', fontsize=16)
plt.grid(True)
plt.show()

# %%
# Most affordable borough per day
most_affordable_borough = dfClean.groupby('area')['price'].median().sort_values(ascending=False).reset_index()
print("The most affordable borough in Bangkok:\n")
table = tabulate(most_affordable_borough,headers=['area','Price'],tablefmt='grid')
print(table)

# Plotting the most affordable borough per day
sns.barplot(x='price',y='area', data=most_affordable_borough)
plt.xlabel("Price")
plt.ylabel("Different Boroughs of Cluster")
plt.title("Most affordable borough in Thailand per day")
plt.show()
# Out:
# The most affordable borough in Bangkok:
#
# +----+-----------------------+---------+
# |    | area                  |   Price |
# +====+=======================+=========+
# |  0 | Central Bangkok       |    1529 |
# +----+-----------------------+---------+
# |  1 | Outer Western Bangkok |    1200 |
# +----+-----------------------+---------+
# |  2 | South Bangkok         |    1200 |
# +----+-----------------------+---------+
# |  3 | West Bangkok          |    1100 |
# +----+-----------------------+---------+
# |  4 | North Bangkok         |    1000 |
# +----+-----------------------+---------+
# |  5 | East Bangkok          |     999 |
# +----+-----------------------+---------+

# %%
# plot neighbourhood groups on the basis of latitude and longitude
plt.figure(figsize=(10, 8))
sns.scatterplot(x='longitude', y='latitude', hue='area', data=dfClean)
plt.title('Locations of different neighbourhood groups in Bangkok over a map')
plt.show()

# %%
# Room types in different neighbourhood groups
room_type_neighbourhood_groups = dfClean.groupby(['area', 'room_type'])['room_type'].count()
print('The different room types available in different neighbourhood groups: \n')
room_type_neighbourhood_groups_df = room_type_neighbourhood_groups.reset_index(name='Count')
table = tabulate(room_type_neighbourhood_groups_df, headers=['Neighbourhood Group', 'Room Type', 'Count'], tablefmt='pretty')
print(table)

# Plot the distribution
plt.figure()
sns.countplot(data=dfClean, x='area', hue='room_type')
plt.title('Room types in different neighbourhood groups')
plt.show()
# Out:
# The different room types available in different neighbourhood groups:
#
# +----+-----------------------+-----------------+-------+
# |    |  Neighbourhood Group  |    Room Type    | Count |
# +----+-----------------------+-----------------+-------+
# | 0  |    Central Bangkok    | Entire home/apt | 3079  |
# | 1  |    Central Bangkok    |   Hotel room    |  344  |
# | 2  |    Central Bangkok    |  Private room   | 2177  |
# | 3  |    Central Bangkok    |   Shared room   |  339  |
# | 4  |     East Bangkok      | Entire home/apt |  219  |
# | 5  |     East Bangkok      |   Hotel room    |  10   |
# | 6  |     East Bangkok      |  Private room   |  341  |
# | 7  |     East Bangkok      |   Shared room   |  20   |
# | 8  |     North Bangkok     | Entire home/apt |  283  |
# | 9  |     North Bangkok     |   Hotel room    |  15   |
# | 10 |     North Bangkok     |  Private room   |  492  |
# | 11 |     North Bangkok     |   Shared room   |  15   |
# ...

# %%
# different room types
different_room_types = dfClean['room_type'].value_counts()
df = pd.DataFrame({'Room Types': different_room_types.index, 'Count': different_room_types.values})
print('The top neighbourhood groups which has the most number of properties listed:\n')
table = tabulate(df, headers=["Room Types","Count"],tablefmt='fancy_grid')
print(table)

plt.figure()
plt.title('Different types of room types')
plt.pie(dfClean['room_type'].value_counts(), labels=dfClean['room_type'].value_counts().index, autopct='%1.1f%%', startangle=180)
plt.show()
# Out:
# The top neighbourhood groups which has the most number of properties listed:
#
# ╒════╤═════════════════╤═════════╕
# │    │ Room Types      │   Count │
# ╞════╪═════════════════╪═════════╡
# │  0 │ Entire home/apt │    4769 │
# ├────┼─────────────────┼─────────┤
# │  1 │ Private room    │    4079 │
# ├────┼─────────────────┼─────────┤
# │  2 │ Shared room     │     441 │
# ├────┼─────────────────┼─────────┤
# │  3 │ Hotel room      │     431 │
# ╘════╧═════════════════╧═════════╛

# %%
# distribution of the properties around NYC through a pie chart
neighbourhood_groups = dfClean['area'].value_counts()
df = pd.DataFrame({'area': neighbourhood_groups.index, 'Count': neighbourhood_groups.values})
print('The top neighbourhood groups which has the most number of properties listed:\n')
table = tabulate(df, headers=["Neighbourhood Group","Count"],tablefmt='fancy_grid')
print(table)

plt.figure(figsize=(10, 8))
plt.title('Distribution of properties across Bangkok broughs')
plt.pie(dfClean['area'].value_counts(), labels=dfClean['area'].value_counts().index, autopct='%1.1f%%', startangle=180)
plt.show()
# Out:
# The top neighbourhood groups which has the most number of properties listed:
#
# ╒════╤═══════════════════════╤═════════╕
# │    │ Neighbourhood Group   │   Count │
# ╞════╪═══════════════════════╪═════════╡
# │  0 │ Central Bangkok       │    5939 │
# ├────┼───────────────────────┼─────────┤
# │  1 │ South Bangkok         │    1525 │
# ├────┼───────────────────────┼─────────┤
# │  2 │ North Bangkok         │     805 │
# ├────┼───────────────────────┼─────────┤
# │  3 │ West Bangkok          │     783 │
# ├────┼───────────────────────┼─────────┤
# │  4 │ East Bangkok          │     590 │
# ├────┼───────────────────────┼─────────┤
# │  5 │ Outer Western Bangkok │      77 │
# ╘════╧═══════════════════════╧═════════╛

# %%
# find the top 10 costly neighbourhoods in NYC
high_priced_neighbourhoods = dfClean.groupby(['neighbourhood'])['price'].mean().sort_values(ascending=False)[:10]
print('The most expensive neighbourhoods: \n')
high_priced_neighbourhoods_df = high_priced_neighbourhoods.reset_index(name='Average Price')
table = tabulate(high_priced_neighbourhoods_df, headers = ['Neighbourhood','Average Price'],tablefmt='grid')
print(table)

# Buat visualisasi
plt.figure(figsize=(10, 6))
sns.barplot(y=high_priced_neighbourhoods.index, x=high_priced_neighbourhoods.values)
plt.ylabel('Neighbourhoods')
plt.xlabel('Average Price per day')
plt.title('Top 10 costliest neighbourhoods')
plt.show()
# Out:
# The most expensive neighbourhoods:
#
# +----+-----------------+-----------------+
# |    | Neighbourhood   |   Average Price |
# +====+=================+=================+
# |  0 | Parthum Wan     |         2320.32 |
# +----+-----------------+-----------------+
# |  1 | Vadhana         |         1997.46 |
# +----+-----------------+-----------------+
# |  2 | Bang Rak        |         1994.64 |
# +----+-----------------+-----------------+
# |  3 | Nong Chok       |         1941.3  |
# +----+-----------------+-----------------+
# |  4 | Khlong Toei     |         1922.23 |
# +----+-----------------+-----------------+
# |  5 | Samphanthawong  |         1895.35 |
# +----+-----------------+-----------------+
# |  6 | Ratchathewi     |         1755.37 |
# +----+-----------------+-----------------+
# |  7 | Yan na wa       |         1740.33 |
# +----+-----------------+-----------------+
# |  8 | Taling Chan     |         1723.18 |
# +----+-----------------+-----------------+
# ...

# %% [markdown]
# Grafik ini menunjukkan "10 wilayah termahal" berdasarkan harga rata-rata per hari. Wawasan utamanya adalah:
#
# - Parthum Wan merupakan wilayah termahal, dengan harga rata-rata per hari sekitar 1.758 THB.
# - Vadhana adalah yang kedua termahal, dengan harga rata-rata per hari sekitar 1.516 THB.
# - Bang Rak, Nong Chok, dan Khlong Toei membentuk kelompok berikutnya dari wilayah-wilayah mahal, semuanya dengan harga rata-rata per hari antara 1.382 THB dan 1.414 THB.
# - Samphanthawong, Ratchathewi, Yan na wa, Taling Chan, dan Bang Kho laen melengkapi 10 wilayah termahal, dengan harga rata-rata berkisar dari 1.195 THB hingga 1.335 THB per hari.
#
# Representasi visual ini memungkinkan perbandingan mudah biaya relatif dari 10 wilayah termahal ini. Grafik ini memberikan gambaran jelas tentang lanskap harga di wilayah ini.

# %%
# find the top 10 cheaper neighbourhoods in NYC
low_priced_neighbourhoods = dfClean.groupby(['neighbourhood'])['price'].mean().sort_values(ascending=True)[:10]
print('The most affordable neighbourhoods: \n')
low_priced_neighbourhoods_df = low_priced_neighbourhoods.reset_index(name='Average Price')
table = tabulate(low_priced_neighbourhoods_df, headers = ['Neighbourhood','Average Price'],tablefmt='grid')
print(table)

# plot the cheaper neighbourhoods
sns.barplot(y=low_priced_neighbourhoods.index,x=low_priced_neighbourhoods.values)
plt.ylabel('Neighbourhoods')
plt.xlabel('Average Price per day')
plt.title('Top 10 cheaper neighbourhoods')
plt.show()
# Out:
# The most affordable neighbourhoods:
#
# +----+-----------------+-----------------+
# |    | Neighbourhood   |   Average Price |
# +====+=================+=================+
# |  0 | Nonthaburi      |            1    |
# +----+-----------------+-----------------+
# |  1 | Lak Si          |         1025.73 |
# +----+-----------------+-----------------+
# |  2 | Don Mueang      |         1089.09 |
# +----+-----------------+-----------------+
# |  3 | Lat Krabang     |         1145.33 |
# +----+-----------------+-----------------+
# |  4 | Phasi Charoen   |         1147.91 |
# +----+-----------------+-----------------+
# |  5 | Pra Wet         |         1149.46 |
# +----+-----------------+-----------------+
# |  6 | Min Buri        |         1166.75 |
# +----+-----------------+-----------------+
# |  7 | Bang Khun thain |         1173.5  |
# +----+-----------------+-----------------+
# |  8 | Bang Sue        |         1182.92 |
# +----+-----------------+-----------------+
# ...

# %% [markdown]
# Grafik ini menunjukkan "10 wilayah termurah" berdasarkan harga rata-rata per hari. Wawasan utamanya adalah:
#
# - Nonthaburi adalah wilayah termurah, dengan harga rata-rata per hari sekitar 683 THB.
# - Lak Si adalah wilayah kedua termurah, dengan harga rata-rata per hari sekitar 703 THB.
# - Don Mueang, Lat Krabang, dan Phasi Charoen membentuk kelompok berikutnya dari wilayah-wilayah termurah, semuanya dengan harga rata-rata per hari antara 745 THB dan 801 THB.
# - Pra Wet, Min Buri, Bang Khun thain, Bang Sue, dan Bang Khen melengkapi 10 wilayah termurah, dengan harga rata-rata berkisar dari 789 THB hingga 885 THB per hari.
#
# Representasi visual ini memungkinkan perbandingan mudah biaya relatif dari 10 wilayah termurah ini.
